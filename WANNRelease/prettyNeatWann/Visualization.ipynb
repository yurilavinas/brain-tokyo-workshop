# %%
# -- View Topology of Network
# Lighter color connections are connected to earlier layers (NOT weight strength)
import vis as nv
import numpy as np
from matplotlib import pyplot as plt

# %%
nv.viewInd('champions/biped.out','bipedhard')
# Out:
# # of Connections in ANN:  338
# (<Figure size 1000x1000 with 1 Axes>, <AxesSubplot:>)

# %%
# Load stats:
"""
# Rows: [generations]
# Cols:
0: evaluations (one evaluation of one individual -- may be multiple rollouts)
1: median fitness 
2: top variance (higher variance ever)
3: maximum fitness
4: top fitness (best fitness ever)
5: peak fitness (fitness earned with best single weight value by max individual)
6: median # of nodes in population
7: median # of connections in population]
"""
stats = np.loadtxt('champions/biped_stats.out', delimiter=',')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-fed65d2c36ff> in <module>
#      12 7: median # of connections in population]
#      13 """
# ---> 14 stats = np.loadtxt('champions/biped_stats.out', delimiter=',')
#
# /usr/local/lib/python3.9/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# /usr/local/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# /usr/local/lib/python3.9/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: champions/biped_stats.out not found.

# %%
len(stats[1,:])

# %%
# Plot fitness progress:
plt.figure(figsize=(12,4))
plt.grid(linestyle='--', linewidth=0.1)
plt.plot(stats[:,1], label="Median Fitness")
plt.plot(stats[:,2], label="Max Fitness")
plt.plot(stats[:,3], label="Top Fitness")
plt.plot(stats[:,4], label="Peak Fitness")
plt.legend()
plt.grid(linestyle=':', linewidth=2)
plt.xlabel('Generations')
plt.ylabel('Fitness')


plt.title('Sample Run of WANN - Bipedal')
