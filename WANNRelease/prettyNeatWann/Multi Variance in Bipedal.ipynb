# %%
# !python3 wann_train.py -n 16 -p p/biped_var_multi.json -o multi_var #.container { width:100% !important; }
# Out:
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# Initializing population...
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# 	*** Running with hyperparameters:  p/biped_var_multi.json 	***
# ...
