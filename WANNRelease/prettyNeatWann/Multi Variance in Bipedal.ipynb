# %%
rm -r log/multi_var_*
# Out:
# rm: log/multi_var_*: No such file or directory

# %%
# !python3 wann_train.py -n 1 -p p/biped_var_multi.json -o multi_var #.container { width:100% !important; }
# Out:
# Initializing population...
# /usr/local/lib/python3.9/site-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# 0 	 |---| Elite Fit: 8.18 	|---| Best Fit:  8.18 	|---| Peak Fit:  120.35 	|---| Best Var:  160.44
# 1 	 |---| Elite Fit: 11.37 	|---| Best Fit:  11.37 	|---| Peak Fit:  358.07 	|---| Best Var:  486.36
# 2 	 |---| Elite Fit: 11.37 	|---| Best Fit:  11.37 	|---| Peak Fit:  358.07 	|---| Best Var:  486.36
# 3 	 |---| Elite Fit: 11.37 	|---| Best Fit:  11.37 	|---| Peak Fit:  358.07 	|---| Best Var:  486.36
# 4 	 |---| Elite Fit: 11.37 	|---| Best Fit:  11.37 	|---| Peak Fit:  358.07 	|---| Best Var:  486.36
# 5 	 |---| Elite Fit: 11.75 	|---| Best Fit:  11.75 	|---| Peak Fit:  354.03 	|---| Best Var:  509.69
# 6 	 |---| Elite Fit: 13.94 	|---| Best Fit:  13.94 	|---| Peak Fit:  440.09 	|---| Best Var:  575.14
# ...
