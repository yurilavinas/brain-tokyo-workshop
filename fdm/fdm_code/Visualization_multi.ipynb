# %%
# -- View Topology of Network
# Lighter color connections are connected to earlier layers (NOT weight strength)
import vis as nv
import numpy as np
from matplotlib import pyplot as plt

# %%
nv.viewInd('log/sswingup_multi_best.out','swingup')
# Out:
# # of Connections in ANN:  308
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-2-e599ac7e03fe> in <module>
# ----> 1 nv.viewInd('log/sswingup_multi_best.out','swingup')
#
# ~/failure_diversity_maximisation/fdm/fdm_code/vis/viewInd.py in viewInd(ind, taskName)
#      32     cmap='terrain',vmin=0,vmax=6)
#      33   drawNodeLabels(G,pos,aVec)
# ---> 34   labelInOut(pos,env)
#      35
#      36   plt.tick_params(
#
# ~/failure_diversity_maximisation/fdm/fdm_code/vis/viewInd.py in labelInOut(pos, env)
#     120
#     121   for i in range(nNode-nOut,nNode):
# --> 122     plt.annotate(labelDict[i], xy=(pos[i][0]+0.1, pos[i][1]), xytext=(pos[i][0]+1.5, pos[i][1]+1.0),\
#     123                arrowprops=dict(arrowstyle="<-",color='k',connectionstyle="angle"))
#     124
#
# KeyError: 117

# %%
# Load stats:
"""
# Rows: [generations]
# Cols:
0: evaluations (one evaluation of one individual -- may be multiple rollouts)
1: median fitness 
2: median variance
3: median novelty 
4: best variance
5: elite variance
6: best variance
7: elite variance
9: top fitness (best fitness ever)
10: peak fitness (fitness earned with best single weight value by max individual)
6: median # of nodes in population
7: median # of connections in population]
"""
stats = np.loadtxt('log/sswingup_multi_stats.out', delimiter=',')

# %%
max(stats[:,2])
# Out:
# 2300.0

# %%
# Plot fitness progress:
plt.figure(figsize=(12,4))
plt.grid(linestyle='--', linewidth=0.1)

plt.plot(stats[:,2], label="Median variance")
plt.plot(stats[:,4], label="Best Variance")
plt.plot(stats[:,5], label="Elite Variance")

plt.legend()
plt.grid(linestyle=':', linewidth=2)
plt.xlabel('Generations')
plt.ylabel('Reward')


plt.title('Var method - Bipedal')
# Out:
# Text(0.5, 1.0, 'Var method - Bipedal')

# %%
# Plot fitness progress:
plt.figure(figsize=(12,4))
plt.grid(linestyle='--', linewidth=0.1)

plt.plot(stats[:,1], label="Median fitness - pop")
plt.plot(stats[:,9], label="Best fitness")
plt.plot(stats[:,10], label="Best Peak Fitness")

plt.legend()
plt.grid(linestyle=':', linewidth=2)
plt.xlabel('Generations')
plt.ylabel('Reward')


plt.title('Var method - Bipedal')
# Out:
# Text(0.5, 1.0, 'Var method - Bipedal')
